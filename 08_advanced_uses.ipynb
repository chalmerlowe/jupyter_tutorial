# %% [markdown]
# # Advanced uses
# ## matplotlib, numpy, beakerx and pandas, oh my!
#
# <img src="images/logos.3.600.wide.png" width="600" align='right'>
#
# ### Chalmer Lowe
#
# ---

# %% [markdown]
# # Objectives
# ---

# %% [markdown]
# By the end of this lesson, students will be able to:
#
# * Use tools such as pandas within a Jupyter Notebook
# * Use visualization tools such as matplotlib to create and display graphs
# * Use correlated panels to see changes reflected in real time

# %% [markdown]
# # Viewing pandas objects
# ---

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_files/log_file_1000.csv', header=None, 
                 names=['name', 'email', 'fmip', 'toip', 'datetime', 'lat', 'long', 'payloadsize'])

# %%
df
# Out:
#                  name                     email             fmip  \
# 0         barry allen        ballen@jleague.org  155.130.121.215
# 1        arthur curry        acurry@jleague.org  106.152.115.161
# 2          john jones        jjones@jleague.org    60.15.193.250
# 3          wally west         wwest@jleague.org   190.214.22.201
# 4        arthur curry        acurry@jleague.org     60.15.193.74
# 5          ray palmer       rpalmer@jleague.org  106.152.114.248
# 6        victor stone        vstone@jleague.org     60.15.193.95
# 7         kyle rayner       krayner@jleague.org    220.211.18.48
# 8          clark kent         ckent@jleague.org  106.152.114.248
# 9      barbara gordon       bgordon@jleague.org     60.15.193.74
# 10        bruce wayne        bwayne@jleague.org    220.211.18.31
# 11         wally west         wwest@jleague.org   190.214.22.116
# 12         ray palmer       rpalmer@jleague.org    155.130.121.6
# ...

# %%
# display a DataFrame column, a Series:
# The display is slightly different

df['name']
# Out:
# 0           barry allen
# 1          arthur curry
# 2            john jones
# 3            wally west
# 4          arthur curry
# 5            ray palmer
# 6          victor stone
# 7           kyle rayner
# 8            clark kent
# 9        barbara gordon
# 10          bruce wayne
# 11           wally west
# 12           ray palmer
# 13           wally west
# 14          barry allen
# 15         diana prince
# 16         arthur curry
# 17           john jones
# 18           john jones
# 19       barbara gordon
# 20         diana prince
# 21         diana prince
# 22           wally west
# 23         diana prince
# 24           john jones
# 25           john jones
# 26           hal jordan
# 27           hal jordan
# 28          kara zor-el
# 29     john constantine
#              ...
# 970          clark kent
# 971        victor stone
# 972         dinah lance
# 973          john jones
# 974         dinah lance
# 975      barbara gordon
# 976      barbara gordon
# ...

# %%
son_only = df.name[df.name.str.contains('son')]

# %%
son_only.value_counts()
# Out:
# billy batson    52
# dick grayson    51
# Name: name, dtype: int64

# %%
# When we run two commands in a cell at the same time, by default
#     Jupyter will only display one result at a time.
#     It defaults to showing only the last result...

df.payloadsize.mean()
df.payloadsize.median()
# Out:
# 495129.859
# 495761.5

# %%
# There is a way to override this by setting the IPython ast_node_interactivity setting

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.payloadsize.mean()
df.payloadsize.median()
# Out:
# 495129.859
# 495761.5

# %% [markdown]
# # Use visualization tools such as matplotlib
# ---

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

# %%
x = np.linspace(0, 10)
line, = plt.plot(x, np.sin(x), '--', linewidth=2)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, projection='polar')
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)

plt.show()

# %% [markdown]
# # Bokeh: interactive visualizations
# ---

# %%
from bokeh.io import show, output_notebook
from bokeh.models import LogColorMapper
from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure

from bokeh.sampledata.us_counties import data as counties
from bokeh.sampledata.unemployment import data as unemployment

palette.reverse()

counties = {
    code: county for code, county in counties.items() if county["state"] == "ga"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment.get(county_id, 0.0) for county_id in counties]
color_mapper = LogColorMapper(palette=palette)

data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
)

TOOLS = "pan,wheel_zoom,reset,hover,save"

p = figure(
    title="Georgia Unemployment, 2009", tools=TOOLS,
    x_axis_location=None, y_axis_location=None,
    tooltips=[
        ("Name", "@name"), ("Unemployment rate)", "@rate%"), ("(Long, Lat)", "($x, $y)")
    ])
p.grid.grid_line_color = None
p.hover.point_policy = "follow_mouse"

p.patches('x', 'y', source=data,
          fill_color={'field': 'rate', 'transform': color_mapper},
          fill_alpha=0.7, line_color="white", line_width=0.5)

output_notebook()
show(p)
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='44f8d39c-61c1-4e14-8f02-8a05dbbeeac0',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='d40959c8-a93a-408a-bb2b-134a70626faa',
#         callback=None,
#         data={'rate': [9.7,
#           12.6,
#           8.5,
#           9.1,
#           11.6,
#           6.7,
#           11.1,
#           13.3,
#           15.3,
#           12.4,
#           10.0,
#           9.7,
#           11.6,
#           8.7,
#           8.1,
#           9.0,
#           12.2,
#           12.7,
#           11.1,
#           9.1,
#           9.3,
#           10.8,
#           8.0,
#           10.6,
#           8.5,
#           14.6,
#           11.4,
#           9.5,
#           7.0,
#           8.2,
#           12.3,
#           11.0,
#           9.6,
#           16.8,
#           9.0,
#           7.0,
#           11.9,
#           10.0,
#           9.5,
#           12.1,
#           9.0,
#           10.1,
#           10.7,
# ...

# %% [markdown]
# # More about panels
# ---

# %% [markdown]
# One element of particular use on the File Browser right-click menu is the `Open With` submenu.
#
# The `Open With` submenu provides you with the ability to open files with particular viewers, depending on the type of file.
#
# In the example shown below, the `Open With` submenu provides the ability to display the selected `json` file with:
#
# * a json renderer
# * a text editor
# * and several other options
#
# <img src="images/viewer_submenu.png" width="420">

# %% [markdown]
# # Experience Points (XP)
# ---

# %% [markdown]
# 1. Open the sample_files folder in the File Browser in the Side Panel.
# 1. Open each of the following files using the appropriate viewer AND with an editor:
#     * `log_file_1000.csv` < CSVTable
#     * `prices.json` < JSON
#     * `sample_markdown.md` < Markdown Preview
#
# 1. Edit each in the editor and note the changes in the Preview panel
# 1. Lastly, open the image with the image previewer
#      * `logos.3.600.wide.png` < Image

# %% [markdown]
# When you complete this exercise, please put your green post-it on your monitor.
#
# If you want to continue on at your own-pace, please feel free to do so.
#
# <img src='./images/green_sticky.300px.png' width='200' style='float:left'>

# %% [markdown]
# Looks like you are done here! **Congrats**.
#
# Please proceed to the next lesson.
